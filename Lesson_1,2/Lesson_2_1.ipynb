# %%
import numpy as np

# %% [markdown]
# Задание 1

# %%
a = np.array([[1,6], [2,8], [3,11], [3,10], [1,7]])

# %%
a
# Out:
# array([[ 1,  6],
#        [ 2,  8],
#        [ 3, 11],
#        [ 3, 10],
#        [ 1,  7]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
mean_a =  np.mean(a, axis = 0)

# %%
mean_a
# Out:
# array([2. , 8.4])

# %% [markdown]
# Задание 2

# %%
a_centered = np.array([a[0]-mean_a, a[1]-mean_a, a[2]-mean_a, a[3]-mean_a, a[4]-mean_a])

# %%
a_centered
# Out:
# array([[-1. , -2.4],
#        [ 0. , -0.4],
#        [ 1. ,  2.6],
#        [ 1. ,  1.6],
#        [-1. , -1.4]])

# %% [markdown]
# Задание 3

# %%
a_centered_sp = a_centered.T[0] @ a_centered.T[1]
a_centered_sp
# Out:
# 8.0

# %%
a_centered_sp / (a_centered.shape[0] - 1)
# Out:
# 2.0

# %% [markdown]
# Задание 5

# %%
np.cov(a.T)[0, 1]
# Out:
# 2.0
